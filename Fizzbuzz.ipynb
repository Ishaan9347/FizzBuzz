# %%
# !pip install pytest
# Out:
# Requirement already satisfied: pytest in /root/venv/lib/python3.9/site-packages (8.3.4)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /root/venv/lib/python3.9/site-packages (from pytest) (1.2.2)
# Requirement already satisfied: iniconfig in /root/venv/lib/python3.9/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.9/site-packages (from pytest) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /root/venv/lib/python3.9/site-packages (from pytest) (1.5.0)
# Requirement already satisfied: tomli>=1 in /root/venv/lib/python3.9/site-packages (from pytest) (2.2.1)

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pytest test_fizzbuzz.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.9.20, pytest-8.3.4, pluggy-1.5.0
# rootdir: /datasets/_deepnote_work
# collected 1 item
#
# test_fizzbuzz.py .                                                       [100%]
#
# ============================== 1 passed in 3.84s ===============================

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8c7d98ac-35fb-4a93-8263-3df15984e580' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
